# %%
import time
import os
from selenium import webdriver
from selenium.common.exceptions import UnexpectedAlertPresentException
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import re

# %%
linkToCdir = os.path.dirname('__file__')
pathToTextFiles = os.path.dirname(os.path.join(linkToCdir, 'facebook-friends.txt/'))
g = open(pathToTextFiles,"a+")

# %%
def openFrindsPage():
    driver.maximize_window()
    driver.implicitly_wait(20)
    driver.get("http://www.facebook.com")
    driver.find_element_by_id("email").clear()
    driver.find_element_by_id("email").send_keys("xxxxxxxx")
    driver.find_element_by_id("pass").send_keys("xxxxxxxx")
    driver.find_element_by_id("loginbutton").click()
    driver.find_element_by_xpath('//*[@id="navItem_1572366616371383"]/a/div').click()
    driver.find_element_by_xpath('//*[@id="pagelet_bookmark_seeall"]/div/div/div[1]/div/div[1]/div/a[2]').click()
    return scrollToLastFriend()

# %%
def scrollToLastFriend():
    text = driver.page_source.find("More About You")
    while text == -1:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        text = driver.page_source.find("More About You")
    return getFriendsList()

# %%
def getFriendsList():
    my_soup = BeautifulSoup(driver.page_source, 'lxml')
    data = my_soup.find_all('div', class_="fsl fwb fcb")
    count = 0
    for i in data:
        new = re.findall('(?<=hc_location=friends_tab">).*?(?=</a>)', str(i))
        for j in new:
            print j
            count +=1
            names = j + "\n"
            g.write(names)
    return count

# %%
driver = webdriver.Chrome("/home/emeka/codes/tools/chromedriver")
openFrindsPage()
# Out:
# Udo Nkwocha
# Joseph Omoba
# Jeni Fa
# Clinton Junior
# Obinwa Rosemary Ositadinma
# Nkwocha Chidi Caleb
# Debbygurl Nkwocha
# Yetunde Ganiyu
# Ezeocha M. Samuel
# Samuel Uche
# Segun O'Law
# Oluwatobiloba Olayinka
# Akinseye Oluwole Sylvester
# Omobolaji Afolabi
# Rokky Nicki Onitemi
# Abah Anthony
# Michel Thomas
# Augustine Nkwocha
# Olamide Olawoye
# Cynthia Ikelusi
# Olayinka Oladele
# Siir Phillip
# Etz Holuwatohsyn
# Chidi Nkwocha
# Ugonna Fidelis
# Malachi Nkwocha
# Ayam Gab Cliton
# Favour Udoha Poshfaivytouch
# Olamide Akerele
# Adejoke Ayun
# Ebikhumi Olere Marian
# Chris Pee
# Imabong Joseph
# Mosunmola Alimi
# Jhaine Ofurum
# Emmanuel Ferdinand
# Afolabi Taiwo
# Celine Williams
# David Dennixo
# Khay Desiigner
# Ezekiel Oluwadamilola Alo
# Ejobs Peace
# Oluwaseun Finext Showunmi
# Soliu Sa'eed Solidarity
# Yohan Iliya
# Cool Demmy
# Esther Ezekiel
# Daz Onabule Damola
# Segun Olayinka
# Emeka Godwin
# Ezeama Chinedu
# Shakur Olaitan Lammy Shakur
# Ikenna Amadi
# Benedicta Nkechi
# Chexx Mickel
# Blessed Fraklin
# Oluwa Sena
# Alo Daniel
# Henryy Ikediego
# Victor David Jnr
# Odugbesan David
# Dennix Ortiz
# Abeke Dash
# David Dennixo
# Marie Barbie
# Emeka Agwaraonye
# Iwujidarlington Iwuji
# Ife Dayo Jatto
# Odebiyi Boluwatife Victor
# Ofure Peace Oziegbe
# Olutayo Olalekan
# Innocent Isidore
# Wayne Idan Barhddest
# Fatimah Adiyah Muhammed
# Micheal Lele
# Aishat Shittu
# Rasheed Dada
